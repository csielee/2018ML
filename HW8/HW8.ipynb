# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # learn t-SNE(Stochastic Neighbor Embedding) from implementation
#
# [soure](https://lvdmaaten.github.io/tsne/)
#
# - Similarity of data points in high dimensionalilty
#
# $$ p_{j|i} = \frac{exp(-||x_i - x_j||^2/(2\sigma_i^2))}{\sum_{k \neq i} exp(-||x_i - x_k||^2/(2\sigma_i^2))} $$
#
# - Similarity of data points in low dimensionalilty
#
# $$ q_{j|i} = \frac{exp(-||y_i - y_j||^2)}{\sum_{k \neq i} exp(-||y_i - y_k||^2)} $$
#
# preserve pairwise similarity between high-d and low-d : $p_{j|i} = q_{j|i}$
# use KL divergence to be cose
#
# $$ C = \sum_i KL(P_i || Q_i) = \sum_i\sum_jp_{j|i}log\frac{p_{j|i}}{q_{j|i}} $$
#
#
# - different $\sigma_i$ cause different entropy
#     - big $\sigma_i$, high entropy
#     - small $\sigma_i$, low entropy
#
# define perplexity to help find good $\sigma_i$
#
# - perplexity
#
# $$ Perp(P_i) = 2^{H(P_i)}, H(P_i) = -\sum_jp_{j|i}log_2p_{j|i}$$
#
# for each $i$, use binary to search suitable $\sigma_i$

# %% [markdown]
# - in implementation `Hbeta`
#
# use some trick to calculate entropy
#
# $$ D_{j|i} = -||x_i - x_j||^2, \text{beta} = \frac{1}{2 \sigma_i^2}, p_{j|i} = \frac{exp(-D_{j|i}*beta)}{\sum_j exp(-D_{j|i}*beta)} \\
# H(P_i) = -\sum_jp_{j|i}log_2p_{j|i} = \sum_j \frac{exp(-D_{j|i}*beta)}{\sum_j D_{j|i}*beta} log_2\frac{\sum_j exp(-D_{j|i}*beta)}{exp(-D_{j|i}*beta)} \\
# = \sum_j \frac{exp(-D_{j|i}*beta)}{\sum_j exp(-D_{j|i}*beta)} (log(\sum_j exp(-D_{j|i}*beta)) - log (exp(-D_{j|i}*beta))) \\
# = \sum_j \frac{exp(-D_{j|i}*beta) log(\sum_j D_{j|i}*beta)}{\sum_j exp(-D_{j|i}*beta)} + \frac{exp(-D_{j|i}*beta)D_{j|i}*beta)}{\sum_j exp(-D_{j|i}*beta)} \\
# = log(sumP) + \frac{\sum_j p_jD_{j|i}beta}{sumP}, sumP = \sum_j p_j,p_j = exp(-D_{j|i}*beta)
# $$

# %%
def pca(X=np.array([]), no_dims=50):
    """
        Runs PCA on the NxD array X in order to 
        reduce its dimensionality to no_dims dimensions.
    """
    
    # get n and d from shape
    (n, d) = X.shape
    
    # become X as centered data
    # use mean get 1xd array from n datas
    # and then expend to n*d array
    # sub with X
    X = X - np.tile(np.mean(X, axis=0), (n,1))
    
    # maximize W^T S W, solve eigen problem
    # S is covariance matrix
    (l, M) = np.linalg.eig(np.matmul(X.T, X))
    
    # use max no_dims principal compoment to reduce dimensions
    Y = np.matmul(X, M[:, 0:no_dims])
    return Y

def Hbeta(D=np.array([]), beta=1.0):
    """
        Compute the perplexity and the P-row for a specific value of the
        precision of a Gaussian distribution.
    """
    
    # compute P-row and corresponding perplexity
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    
    return H, P

def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """
    
    # initialize some variables
    
    # compute pairwise distances
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    
    
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)
    
    # loop over all datapoints
    for i in range(n):
        
        # compute the Gaussian kernel and entropy for the current precision
        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])
        
        # evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:
            
            # if not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.
            
            # recompute the value
            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1
        
        # set the final row of P
        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP
        
    # return final P-matrix
    return P

# %%
np.concatenate((np.r_[0:3], np.r_[3+1:10]))
# Out:
# array([0, 1, 2, 4, 5, 6, 7, 8, 9])

# %%
# load minst2500 dataset
X = np.loadtxt("mnist2500_X.txt")
labels = np.loadtxt("mnist2500_labels.txt")

X.shape, labels.shape
# Out:
# ((2500, 784), (2500,))

# %% [markdown]
# # Add symmetric SNE
#
# modify Q and gradient

# %%
def __tsne_gradient_descent(Y, dY, iY, gains, min_gain, momentum, eta):
    """
        return Y iY gains
    """
    gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
            (gains * 0.8) * ((dY > 0.) == (iY > 0.))
    gains[gains < min_gain] = min_gain
    iY = momentum * iY - eta * (gains * dY)
    Y = Y + iY
    Y = Y - np.tile(np.mean(Y, 0), (Y.shape[0], 1))
    
    return Y, iY, gains

def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0, SNE=False):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """
    
    # check inputs
    if not X.dtype == 'float':
        raise AttributeError("array X should have type float")
    if round(no_dims) != no_dims:
        raise AttributeError("number of dimensions should be an integer")
    
    # initialize variables
    
    # reduce X to initial_dims dimensions
    # because eigen vector is complex, just get real part
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))
    C = []
    Q = np.zeros((n, n))
    
    if SNE:
        # use same random initial values
        Y_SNE = Y.copy()
        dY_SNE = np.zeros((n, no_dims))
        iY_SNE = np.zeros((n, no_dims))
        gains_SNE = np.ones((n, no_dims))
        C_SNE = []
        Q_SNE = np.zeros((n, n))
    
    # compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.
    P = np.maximum(P, 1e-12)
    
    # run iterations
    for iter in range(max_iter):
        
        # compute pairwise affinities Q
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)
        if SNE:
            sum_Y_SNE = np.sum(np.square(Y_SNE), 1)
            num_SNE = -2. * np.dot(Y_SNE, Y_SNE.T)
            num_SNE = np.add(np.add(num_SNE, sum_Y_SNE).T, sum_Y_SNE)
            num_SNE = np.exp(-1*num_SNE)
            num_SNE[range(n), range(n)] = 0.
            Q_SNE = num_SNE / np.sum(num_SNE)
            Q_SNE = np.maximum(Q_SNE, 1e-12)
        
        # compute gradient
        PQ = P - Q
        if SNE:
            PQ_SNE = P - Q_SNE
        for i in range(n):
            dY[i, :] = np.sum(
                np.tile(
                    PQ[:, i] * num[:, i], 
                    (no_dims, 1)
                ).T * (Y[i, :] - Y), 
                0
            )
            if SNE:
                dY_SNE[i, :] = np.sum(
                    np.tile(
                        PQ_SNE[:,i], 
                        (no_dims, 1)
                    ).T * (Y_SNE[i, :] - Y_SNE), 
                    0
                )
        
        # perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
            
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))
        
        if SNE:
            Y_SNE, iY_SNE, gains_SNE = __tsne_gradient_descent(
                Y_SNE, 
                dY_SNE, 
                iY_SNE, 
                gains_SNE, 
                min_gain,
                momentum, 
                eta
            )
    
        # compute current value of cost function
        # use KL divergense
        if (iter + 1) % 10 == 0:
            C += [np.sum(P * np.log(P / Q))]
            if SNE:
                C_SNE += [np.sum(P * np.log(P / Q_SNE))]
                #print('[{}] tsne error : {:.4f}, s-sne error : {:.4f}'.format(
                #    iter+1, 
                #    C[-1], 
                #    C_SNE[-1])
                #)
            #else:
                #print('[{}] tsne error : {:.4f}'.format(iter+1, C[-1]))
    
        # stop lying about P-values
        if iter == 100:
            P = P / 4.
    
    # return solution
    if not SNE:
        return Y, P, Q, C
    else:
        return (Y, Y_SNE), P, (Q, Q_SNE), (C, C_SNE)

# %%
# %%time
Y = tsne(X, 2, 50, 20.0)
# Out:
# CPU times: user 17min 5s, sys: 8min 51s, total: 25min 57s
# Wall time: 14min 23s

# %%
# %%time
Ys, P, Qs, Cs = tsne(X, 2, 50, 20.0, SNE=True)
# Out:
# [10] tsne error : 23.4507, s-sne error : 23.2207
# [20] tsne error : 21.0605, s-sne error : 19.0653
# [30] tsne error : 18.2710, s-sne error : 17.8340
# [40] tsne error : 17.0372, s-sne error : 17.4557
# [50] tsne error : 16.5243, s-sne error : 17.1812
# [60] tsne error : 16.3073, s-sne error : 17.1560
# [70] tsne error : 16.1821, s-sne error : 17.1556
# [80] tsne error : 16.0907, s-sne error : 17.1288
# [90] tsne error : 16.0275, s-sne error : 17.1312
# [100] tsne error : 15.9772, s-sne error : 17.1384
# [110] tsne error : 2.3515, s-sne error : 2.3188
# [120] tsne error : 2.1204, s-sne error : 2.1596
# [130] tsne error : 1.9311, s-sne error : 2.1630
# [140] tsne error : 1.7872, s-sne error : 2.1826
# [150] tsne error : 1.6770, s-sne error : 2.1906
# [160] tsne error : 1.5909, s-sne error : 2.1890
# [170] tsne error : 1.5220, s-sne error : 2.1866
# [180] tsne error : 1.4658, s-sne error : 2.1859
# [190] tsne error : 1.4194, s-sne error : 2.1864
# [200] tsne error : 1.3804, s-sne error : 2.1869
# [210] tsne error : 1.3473, s-sne error : 2.1871
# [220] tsne error : 1.3191, s-sne error : 2.1863
# [230] tsne error : 1.2948, s-sne error : 2.1856
# [240] tsne error : 1.2737, s-sne error : 2.1857
# [250] tsne error : 1.2553, s-sne error : 2.1858
# [260] tsne error : 1.2389, s-sne error : 2.1858
# [270] tsne error : 1.2242, s-sne error : 2.1858
# [280] tsne error : 1.2110, s-sne error : 2.1858
# [290] tsne error : 1.1991, s-sne error : 2.1858
# [300] tsne error : 1.1884, s-sne error : 2.1858
# [310] tsne error : 1.1786, s-sne error : 2.1858
# [320] tsne error : 1.1697, s-sne error : 2.1858
# [330] tsne error : 1.1616, s-sne error : 2.1858
# [340] tsne error : 1.1542, s-sne error : 2.1858
# [350] tsne error : 1.1473, s-sne error : 2.1858
# [360] tsne error : 1.1409, s-sne error : 2.1858
# [370] tsne error : 1.1350, s-sne error : 2.1858
# [380] tsne error : 1.1294, s-sne error : 2.1858
# [390] tsne error : 1.1243, s-sne error : 2.1858
# [400] tsne error : 1.1196, s-sne error : 2.1858
# [410] tsne error : 1.1152, s-sne error : 2.1858
# [420] tsne error : 1.1111, s-sne error : 2.1858
# [430] tsne error : 1.1073, s-sne error : 2.1858
# [440] tsne error : 1.1036, s-sne error : 2.1858
# [450] tsne error : 1.1002, s-sne error : 2.1858
# [460] tsne error : 1.0970, s-sne error : 2.1858
# [470] tsne error : 1.0940, s-sne error : 2.1858
# [480] tsne error : 1.0911, s-sne error : 2.1858
# [490] tsne error : 1.0884, s-sne error : 2.1858
# [500] tsne error : 1.0859, s-sne error : 2.1858
# [510] tsne error : 1.0834, s-sne error : 2.1858
# [520] tsne error : 1.0811, s-sne error : 2.1858
# [530] tsne error : 1.0789, s-sne error : 2.1858
# [540] tsne error : 1.0768, s-sne error : 2.1858
# [550] tsne error : 1.0749, s-sne error : 2.1858
# [560] tsne error : 1.0730, s-sne error : 2.1858
# [570] tsne error : 1.0712, s-sne error : 2.1858
# [580] tsne error : 1.0695, s-sne error : 2.1858
# [590] tsne error : 1.0678, s-sne error : 2.1858
# [600] tsne error : 1.0663, s-sne error : 2.1858
# [610] tsne error : 1.0648, s-sne error : 2.1858
# [620] tsne error : 1.0633, s-sne error : 2.1858
# [630] tsne error : 1.0620, s-sne error : 2.1858
# [640] tsne error : 1.0606, s-sne error : 2.1858
# [650] tsne error : 1.0594, s-sne error : 2.1858
# [660] tsne error : 1.0582, s-sne error : 2.1858
# [670] tsne error : 1.0570, s-sne error : 2.1858
# [680] tsne error : 1.0559, s-sne error : 2.1858
# [690] tsne error : 1.0548, s-sne error : 2.1858
# [700] tsne error : 1.0538, s-sne error : 2.1858
# [710] tsne error : 1.0528, s-sne error : 2.1858
# [720] tsne error : 1.0518, s-sne error : 2.1858
# [730] tsne error : 1.0509, s-sne error : 2.1858
# [740] tsne error : 1.0500, s-sne error : 2.1858
# [750] tsne error : 1.0491, s-sne error : 2.1858
# [760] tsne error : 1.0483, s-sne error : 2.1858
# [770] tsne error : 1.0475, s-sne error : 2.1858
# [780] tsne error : 1.0467, s-sne error : 2.1858
# [790] tsne error : 1.0460, s-sne error : 2.1858
# [800] tsne error : 1.0453, s-sne error : 2.1858
# [810] tsne error : 1.0446, s-sne error : 2.1858
# [820] tsne error : 1.0439, s-sne error : 2.1858
# [830] tsne error : 1.0432, s-sne error : 2.1858
# [840] tsne error : 1.0426, s-sne error : 2.1858
# [850] tsne error : 1.0419, s-sne error : 2.1858
# [860] tsne error : 1.0413, s-sne error : 2.1858
# [870] tsne error : 1.0408, s-sne error : 2.1858
# [880] tsne error : 1.0402, s-sne error : 2.1858
# [890] tsne error : 1.0397, s-sne error : 2.1858
# [900] tsne error : 1.0391, s-sne error : 2.1858
# [910] tsne error : 1.0386, s-sne error : 2.1858
# [920] tsne error : 1.0381, s-sne error : 2.1858
# [930] tsne error : 1.0376, s-sne error : 2.1858
# [940] tsne error : 1.0371, s-sne error : 2.1858
# [950] tsne error : 1.0367, s-sne error : 2.1858
# [960] tsne error : 1.0362, s-sne error : 2.1858
# [970] tsne error : 1.0358, s-sne error : 2.1858
# [980] tsne error : 1.0353, s-sne error : 2.1858
# [990] tsne error : 1.0349, s-sne error : 2.1858
# [1000] tsne error : 1.0345, s-sne error : 2.1858
# CPU times: user 36min 11s, sys: 18min 17s, total: 54min 28s
# Wall time: 32min 32s

# %%
plt.scatter(Ys[0][:,0], Ys[0][:,1], s=10, c=labels)

# %%
def showByClustering(Y, labels, size=20, title=''):
    plt.figure(figsize=(10,7.5))
    plt.title(title)
    for l in np.unique(labels):
        plt.scatter(Y[labels==l,0], Y[labels==l,1], s=size, label=str(int(l)))
    plt.legend()
    plt.show()

def showCostCurve(Cs, labels=None, title=''):
    plt.figure(figsize=(10,7.5))
    plt.title(title)
    if type(labels) == type(None):
        labels = ['']*len(Cs)
    
    for idx, C in enumerate(Cs):
        plt.plot(C, label=labels[idx])
    
    plt.xlabel('Iterations per 10')
    plt.ylabel('KL divergence (Cost)')
    plt.legend()
    plt.show()

# %%
showByClustering(Ys[0], labels, title='t-SNE')
showByClustering(Ys[1], labels, title='symmetric SNE')

# %%
showCostCurve(Cs, labels=['t-SNE', 'symmetric SNE'])

# %%
np.savetxt('./datas/t-SNE.txt', Ys[0])
np.savetxt('./datas/s-SNE.txt', Ys[1])

# %%
perplexitys = 2**np.linspace(1.0,10,num=10)
Ys_diffp = {}
P_diffp = {}
Qs_diffp = {}
Cs_diffp = {}

# %%
# %%time
filepath='./datas/{}-{:.0f}.txt'
for p in perplexitys:
    Ys_diffp[p], P_diffp[p], Qs_diffp[p], Cs_diffp[p] = tsne(X, 2, 50, p, SNE=True)
    np.savetxt(filepath.format('t-SNE', p), Ys[0])
    np.savetxt(filepath.format('s-SNE', p), Ys[1])

# %%
X_PCA = pca(X, 50).real

# %%
# %%time
perplexity = 20.0
P_noPCA = x2p(X, perplexity=perplexity)
# Out:
# CPU times: user 36.5 s, sys: 631 ms, total: 37.1 s
# Wall time: 35.3 s

# %%
# %%time
P_PCA = x2p(X_PCA, perplexity=perplexity)
# Out:
# CPU times: user 33 s, sys: 525 ms, total: 33.5 s
# Wall time: 32.8 s

# %%
plt.imshow(np.log(P_noPCA))
plt.show()
plt.imshow(np.log(P_PCA))
plt.show()
# Out:
# /home/grass0756110/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /home/grass0756110/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
np.sum((P_noPCA - P_PCA)**2)
# Out:
# 42.28044078945112
